# %% [markdown]
# # Jupyter Notebook Basics – Practical Task 1
#
# This notebook demonstrates:
# - Basic Markdown usage
# - Reading a CSV file using pandas
# - Plotting data using matplotlib
#
# This task is part of the Springer Capital LLM internship onboarding.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    "Day": ["Mon", "Tue", "Wed", "Thu", "Fri"],
    "Sales": [120, 150, 90, 180, 200]
}

df = pd.DataFrame(data)
df
# Out:
#    Day  Sales
# 0  Mon    120
# 1  Tue    150
# 2  Wed     90
# 3  Thu    180
# 4  Fri    200

# %%
df.to_csv("sales_data.csv", index=False)

# %%
df = pd.read_csv("sales_data.csv")
df
# Out:
#    Day  Sales
# 0  Mon    120
# 1  Tue    150
# 2  Wed     90
# 3  Thu    180
# 4  Fri    200

# %% [markdown]
# # Plotting a graph (matplotlib)

# %%
plt.figure(figsize=(6,4))
plt.plot(df["Day"], df["Sales"], marker='o')
plt.title("Daily Sales")
plt.xlabel("Day")
plt.ylabel("Sales")
plt.grid(True)
plt.show()
